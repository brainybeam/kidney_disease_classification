# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1cKo8-zS4V3D39D-87QGI3b0m8IxV0IT4/view?usp=sharing"

# %%
file_id = url.split("/")[-2]

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney_dataset.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1cKo8-zS4V3D39D-87QGI3b0m8IxV0IT4
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1cKo8-zS4V3D39D-87QGI3b0m8IxV0IT4&confirm=t&uuid=df6da4a3-1693-4ee1-9fd1-bbfc3a603d9a
# To: c:\Personal Projects\Kidney_disease_classification\research\kidney_dataset.zip
# 100%|██████████| 1.63G/1.63G [01:54<00:00, 14.3MB/s]
# 'kidney_dataset.zip'
